# %%
#Import the python package pandas for reading in data
import pandas as pd
import networkx as nx
from networkx.algorithms import bipartite
import community

# %%
#Read in our workshop data with the read_csv
data = pd.read_csv('workshop_survey_data.csv')

# %%
#Show our column names so that we can check that we have everything
print(data.columns)
# Out:
# Index(['Timestamp', 'first_name', 'twitter', 'department', 'university',
#        'place_uni', 'year', 'year_uni', 'today', 'research', 'conference',
#        'experience_in_DH', 'DH_methods', 'rationale', 'DH_means',
#        'hogwarts_house', 'game_of_thrones', 'keanu'],
#       dtype='object')

# %%
#Replace any empty values with a set of empty string
data.fillna('', inplace=True)

# %%
#Show our data
print(data)
# Out:
#             Timestamp    first_name          twitter  \
# 0  5/24/2018 11:39:18           Zoe     @Zoe_LeBlanc
# 1  5/24/2018 11:48:35         Keanu     @keanuthings
# 2  5/28/2018 18:46:25        Golnar     @GolnarNemat
# 3   5/29/2018 8:39:27          Paul
# 4  5/29/2018 11:20:15       Richard
# 5  5/29/2018 12:15:19       Taylor   @taylormariemal
# 6  5/29/2018 14:56:24          Jack
# 7  5/29/2018 18:34:10         Lily        @lilyibrew
# 8  5/29/2018 18:42:59  Sandra Kruse   @Sandi_Peaches
# 9  5/29/2018 20:23:10       Richard       @RLHeppner
#
#                                department                 university  \
# 0                  History, Scholars' Lab     University of Virginia
# 1                  Comparative Literature                       UCLA
# 2         History of Art and Architecture  University of Pittsburgh
# 3                                 English                        CMU
# 4                                 English                        CMU
# 5  English, English as a Second Language        Duquesne University
# 6                                 English                        CMU
# 7         History of Art and Architecture  University of Pittsburgh
# 8                                 English                        CMU
# 9                                     Law       Duquesne University
#
#          place_uni                                        year    year_uni  \
# 0    Nashville, TN                                          6+  2012-01-01
# 1  Los Angeles, CA                                          6+  2012-01-01
# 2   Pittsburgh, PA                                           3  2015-01-01
# 3   Pittsburgh, PA                         interested observer
# 4   Pittsburgh, PA                                           1  2017-01-01
# 5   Pittsburgh, PA                                           2  2016-01-01
# 6   Pittsburgh, PA                                           1  2017-01-01
# 7   Pittsburgh, PA                                           3  2015-01-01
# 8   Pittsburgh, PA  Recent Masters Graduate [one year program]
# 9   Pittsburgh, PA                                   Professor
#
#         today                                           research  \
# 0  2018-06-01  International History, Media History, Text Min...
# 1  2018-06-02  Dogs, Action Movies, Cars Exploding, Digital H...
# 2  2018-06-03  Iranian contemporary and modern art, contempor...
# 3  2018-06-04  IA, digital history, interactive fiction, inst...
# 4  2018-06-05  Political Discourse, Public Rhetorics, Digital...
# 5  2018-06-06  Modernist Poetry, Digital Humanities, Sound St...
# 6  2018-06-07  English literature, literary theory, early mod...
# 7  2018-06-08  modern and contemporary photography, aerial ph...
# 8  2018-06-09  Late 19th and Early 20th Century American Lite...
# 9  2018-06-10  Law, Law and Literature, Law and Rhetoric, Mod...
#
#        conference                                   experience_in_DH  \
# 0  AHA, SHAFR, DH                      I am teaching this workshop 🙃
# 1             MLA  Never heard of it. (This will be a fun week fo...
# 2                         I've taken a course or attended a workshop
# 3                  I've done some readings and tutorials. Maybe I...
# 4       RSA, CCCC  I've done some readings and tutorials. Maybe I...
# 5            MLA          I've taken a course or attended a workshop
# 6             MLA             Heard of it but don't really know much
# 7             CAA         I've taken a course or attended a workshop
# 8             MLA  I've done some readings and tutorials. Maybe I...
# 9            AALS  I've done some readings and tutorials. Maybe I...
#
#                                           DH_methods  \
# 0  Networks, Text Mining, Mapping, Data Visualiza...
# 1  Pedagogy, Machine Learning/AI/buzzword tech stuff
# 2  Networks, Mapping, Data Visualization, Databas...
# 3  Networks, Text Mining, Mapping, Data Visualiza...
# 4  Networks, Text Mining, Mapping, Data Visualiza...
# 5  Data Visualization, Databases, Blogging, Pedag...
# 6  Networks, Text Mining, Data Visualization, Blo...
# 7                Networks, Mapping, Website Creation
# 8  Data Visualization, Databases, Blogging, Pedagogy
# 9  Networks, Text Mining, Data Visualization, Blo...
#
#                                            rationale  \
# 0  Hope to learn about everyone's research intere...
# 1  I want to learn about the Matrix. Also social ...
# 2  I am developing a DH project about modern art ...
# 3  I know some things, but wonder if I lack a goo...
# 4  To learn methods of DH project design + gain f...
# 5  In hopes of understanding DH a bit better for ...
# 6  Primer on variety of DH tools to inform my fut...
# 7
# 8  I'm unsure what role DH will/should/could play...
# 9
#
#                                             DH_means  \
# 0  I've been really excited by digital history fo...
# 1  Currently nothing, but who knows about the fut...
# 2  In addition to make archival data available wi...
# 3  How we have used digital means to communicate,...
# 4  I would take "digital history" (broadly) as th...
# 5  The ability to store a large sum of informatio...
# 6  Network analysis, Data visualization, stylomet...
# 7
# 8  I'm only vaguely familiar with the term, but, ...
# 9  Beats me. But I'm interested in learning about...
#
#                                       hogwarts_house  \
# 0                                          Slytherin
# 1                                         Hufflepuff
# 2                                          Ravenclaw
# 3                                      Kitchen staff
# 4                    I don't care about Harry Potter
# 5                                          Ravenclaw
# 6                                          Slytherin
# 7                                          Slytherin
# 8  I'm sorted Ravenclaw but friends claim I shoul...
# 9                                          Ravenclaw
#
#                                      game_of_thrones  \
# 0                                          Targaryen
# 1                                            Red God
# 2                                              Dorne
# 3  (One of my tests for epic fantasy is, "do I wa...
# 4                                            Red God
# 5                                                Meh
# 6                                            Red God
# 7                                          Targaryen
# 8                                                Meh
# 9                                            Greyjoy
#
#                                                keanu
# 0                             Much Ado About Nothing
# 1                             Who is Keanu Reeves???
# 2                                   He is overrated
# 3                             Much Ado About Nothing
# 4                                              Speed
# 5                                      Matrix Series
# 6                                  Bill & Ted Series
# 7                                   Johnny Mnemonic
# 8  My excuse for not having an answer is that I'm...
# 9                                              Speed

# %%
#Use the splitDataFrameList Method to split up any answers that have multiple values (eg. DH methods or research interests)
def splitDataFrameList(df,target_column,separator):
    ''' df = dataframe to split,
    target_column = the column containing the values to split
    separator = the symbol used to perform the split
    returns: a dataframe with each entry for the target column separated, with each element moved into a new row. 
    The values in the other columns are duplicated across the newly divided rows.
    '''
    def splitListToRows(row,row_accumulator,target_column,separator):
        split_row = row[target_column].split(separator)
        for s in split_row:
            new_row = row.to_dict()
            new_row[target_column] = s
            row_accumulator.append(new_row)
    new_rows = []
    df.apply(splitListToRows,axis=1,args = (new_rows,target_column,separator))
    new_df = pd.DataFrame(new_rows)
    return new_df

# Call the function here, passing in our data and the column name we want to split the values for.
# Try changing the column names
first_split_data = splitDataFrameList(data, 'DH_methods', ',')
second_split_data = splitDataFrameList(first_split_data, 'university', ',')

# %%
# Put our source and target columns to lower case so that they are read as same items
second_split_data['DH_methods'] = second_split_data['DH_methods'].str.lower()
second_split_data['university'] = second_split_data['university'].str.lower()

# %%
# Let's create a network from our table
# First we create the edges from our two columns
G=nx.from_pandas_edgelist(second_split_data, 'first_name', 'university')
# If we want to include other attributes our nodes uncomment these lines
# node_data = second_split_data.set_index('first_name').to_dict('index').items()
# G.add_nodes_from(node_data)

# %%
# Let's check some metrics
# Is this a bipartite graph? 
bipartite_graph = nx.is_bipartite(G)
print(bipartite_graph)
#Is this graph connected?
connected = nx.is_connected(G)
print(connected)
# Out:
# True
# True

# %%
# Let's compare the game of thrones network
GOT = pd.read_csv('GameOfThronesNetwork.txt')
T=nx.from_pandas_edgelist(GOT, 'Source', 'Target')
# Is this a bipartite graph? 
bipartite_graph = nx.is_bipartite(T)
print(bipartite_graph)
#Is this graph connected?
connected = nx.is_connected(T)
print(connected)
# Out:
# False
# True

# %%
df = second_split_data[['first_name', 'university', 'DH_methods']]
# stacked_df = df.stack(level=0)
# stacked_df
df2 = pd.melt(df, id_vars=["DH_methods"], value_vars=["first_name", "university"], value_name='entity').drop('variable', 1)
df = df2
df = pd.crosstab(df.DH_methods, df.entity)
idx = df.columns.union(df.index)
df = df.reindex(index = idx, columns=idx, fill_value=0)
print(df)
T = nx.from_pandas_adjacency(df)
T.edges(data=True)
# degree = nx.degree(T)
# clustering = nx.average_clustering(T)
# partition = community.best_partition(T)
# connected = nx.is_connected(T)
# triangles = nx.triangles(T)
# transitivity = nx.transitivity(T)
# clusters = nx.clustering(T)
# cliques = nx.find_cliques(T)
# bip = bipartite.is_bipartite(T)
# print( bip, connected, triangles, list(cliques), )
# Out:
#                                            blogging   data visualization  \
#  blogging                                         0                    0
#  data visualization                               0                    0
#  databases                                        0                    0
#  machine learning/ai/buzzword tech stuff          0                    0
#  mapping                                          0                    0
#  pedagogy                                         0                    0
#  text mining                                      0                    0
#  website creation                                 0                    0
# Golnar                                            0                    0
# Jack                                              0                    0
# Keanu                                             0                    0
# Lily                                              0                    0
# Paul                                              0                    0
# Richard                                           0                    0
# Sandra Kruse                                      0                    0
# Taylor                                            0                    0
# Zoe                                               0                    0
# cmu                                               0                    0
# data visualization                                0                    0
# duquesne university                               0                    0
# networks                                          0                    0
# pedagogy                                          0                    0
# ucla                                              0                    0
# university of pittsburgh                          0                    0
# university of virginia                            0                    0
#
#                                            databases  \
#  blogging                                          0
#  data visualization                                0
#  databases                                         0
#  machine learning/ai/buzzword tech stuff           0
#  mapping                                           0
#  pedagogy                                          0
#  text mining                                       0
#  website creation                                  0
# Golnar                                             0
# Jack                                               0
# Keanu                                              0
# Lily                                               0
# Paul                                               0
# Richard                                            0
# Sandra Kruse                                       0
# Taylor                                             0
# Zoe                                                0
# cmu                                                0
# data visualization                                 0
# duquesne university                                0
# networks                                           0
# pedagogy                                           0
# ucla                                               0
# university of pittsburgh                           0
# university of virginia                             0
#
#                                            machine learning/ai/buzzword tech stuff  \
#  blogging                                                                        0
#  data visualization                                                              0
#  databases                                                                       0
#  machine learning/ai/buzzword tech stuff                                         0
#  mapping                                                                         0
#  pedagogy                                                                        0
#  text mining                                                                     0
#  website creation                                                                0
# Golnar                                                                           0
# Jack                                                                             0
# Keanu                                                                            0
# Lily                                                                             0
# Paul                                                                             0
# Richard                                                                          0
# Sandra Kruse                                                                     0
# Taylor                                                                           0
# Zoe                                                                              0
# cmu                                                                              0
# data visualization                                                               0
# duquesne university                                                              0
# networks                                                                         0
# pedagogy                                                                         0
# ucla                                                                             0
# university of pittsburgh                                                         0
# university of virginia                                                           0
#
#                                            mapping   pedagogy   text mining  \
#  blogging                                        0          0             0
#  data visualization                              0          0             0
#  databases                                       0          0             0
#  machine learning/ai/buzzword tech stuff         0          0             0
#  mapping                                         0          0             0
#  pedagogy                                        0          0             0
#  text mining                                     0          0             0
#  website creation                                0          0             0
# Golnar                                           0          0             0
# Jack                                             0          0             0
# Keanu                                            0          0             0
# Lily                                             0          0             0
# Paul                                             0          0             0
# Richard                                          0          0             0
# Sandra Kruse                                     0          0             0
# Taylor                                           0          0             0
# Zoe                                              0          0             0
# cmu                                              0          0             0
# data visualization                               0          0             0
# duquesne university                              0          0             0
# networks                                         0          0             0
# pedagogy                                         0          0             0
# ucla                                             0          0             0
# university of pittsburgh                         0          0             0
# university of virginia                           0          0             0
#
#                                            website creation  Golnar  Jack  \
#  blogging                                                 0       1     1
#  data visualization                                       0       1     1
#  databases                                                0       1     0
#  machine learning/ai/buzzword tech stuff                  0       0     0
#  mapping                                                  0       1     0
#  pedagogy                                                 0       1     0
#  text mining                                              0       0     1
#  website creation                                         0       1     1
# Golnar                                                    0       0     0
# Jack                                                      0       0     0
# Keanu                                                     0       0     0
# Lily                                                      0       0     0
# Paul                                                      0       0     0
# Richard                                                   0       0     0
# Sandra Kruse                                              0       0     0
# Taylor                                                    0       0     0
# Zoe                                                       0       0     0
# cmu                                                       0       0     0
# data visualization                                        0       0     0
# duquesne university                                       0       0     0
# networks                                                  0       1     1
# pedagogy                                                  0       0     0
# ucla                                                      0       0     0
# university of pittsburgh                                  0       0     0
# university of virginia                                    0       0     0
#
#                                                    ...            Taylor   \
#  blogging                                          ...                  1
#  data visualization                                ...                  0
#  databases                                         ...                  1
#  machine learning/ai/buzzword tech stuff           ...                  0
#  mapping                                           ...                  0
#  pedagogy                                          ...                  1
#  text mining                                       ...                  0
#  website creation                                  ...                  1
# Golnar                                             ...                  0
# Jack                                               ...                  0
# Keanu                                              ...                  0
# Lily                                               ...                  0
# Paul                                               ...                  0
# Richard                                            ...                  0
# Sandra Kruse                                       ...                  0
# Taylor                                             ...                  0
# Zoe                                                ...                  0
# cmu                                                ...                  0
# data visualization                                 ...                  1
# duquesne university                                ...                  0
# networks                                           ...                  0
# pedagogy                                           ...                  0
# ucla                                               ...                  0
# university of pittsburgh                           ...                  0
# university of virginia                             ...                  0
#
#                                           Zoe  cmu  data visualization  \
#  blogging                                   1    3                   0
#  data visualization                         1    3                   0
#  databases                                  1    3                   0
#  machine learning/ai/buzzword tech stuff    0    2                   0
#  mapping                                    1    2                   0
#  pedagogy                                   1    3                   0
#  text mining                                1    3                   0
#  website creation                           0    3                   0
# Golnar                                      0    0                   0
# Jack                                        0    0                   0
# Keanu                                       0    0                   0
# Lily                                        0    0                   0
# Paul                                        0    0                   0
# Richard                                     0    0                   0
# Sandra Kruse                                0    0                   0
# Taylor                                      0    0                   0
# Zoe                                         0    0                   0
# cmu                                         0    0                   0
# data visualization                          0    1                   0
# duquesne university                         0    0                   0
# networks                                    1    3                   0
# pedagogy                                    0    0                   0
# ucla                                        0    0                   0
# university of pittsburgh                    0    0                   0
# university of virginia                      0    0                   0
#
#                                           duquesne university   networks  \
#  blogging                                                    2         0
#  data visualization                                          1         0
#  databases                                                   1         0
#  machine learning/ai/buzzword tech stuff                     1         0
#  mapping                                                     0         0
#  pedagogy                                                    2         0
#  text mining                                                 1         0
#  website creation                                            2         0
# Golnar                                                       0         0
# Jack                                                         0         0
# Keanu                                                        0         0
# Lily                                                         0         0
# Paul                                                         0         0
# Richard                                                      0         0
# Sandra Kruse                                                 0         0
# Taylor                                                       0         0
# Zoe                                                          0         0
# cmu                                                          0         0
# data visualization                                           1         0
# duquesne university                                          0         0
# networks                                                     1         0
# pedagogy                                                     0         0
# ucla                                                         0         0
# university of pittsburgh                                     0         0
# university of virginia                                       0         0
#
#                                           pedagogy  ucla  \
#  blogging                                        0     0
#  data visualization                              0     0
#  databases                                       0     0
#  machine learning/ai/buzzword tech stuff         0     1
#  mapping                                         0     0
#  pedagogy                                        0     0
#  text mining                                     0     0
#  website creation                                0     0
# Golnar                                           0     0
# Jack                                             0     0
# Keanu                                            0     0
# Lily                                             0     0
# Paul                                             0     0
# Richard                                          0     0
# Sandra Kruse                                     0     0
# Taylor                                           0     0
# Zoe                                              0     0
# cmu                                              0     0
# data visualization                               0     0
# duquesne university                              0     0
# networks                                         0     0
# pedagogy                                         0     1
# ucla                                             0     0
# university of pittsburgh                         0     0
# university of virginia                           0     0
#
#                                           university of pittsburgh   \
#  blogging                                                         1
#  data visualization                                               1
#  databases                                                        1
#  machine learning/ai/buzzword tech stuff                          0
#  mapping                                                          2
#  pedagogy                                                         1
#  text mining                                                      0
#  website creation                                                 2
# Golnar                                                            0
# Jack                                                              0
# Keanu                                                             0
# Lily                                                              0
# Paul                                                              0
# Richard                                                           0
# Sandra Kruse                                                      0
# Taylor                                                            0
# Zoe                                                               0
# cmu                                                               0
# data visualization                                                0
# duquesne university                                               0
# networks                                                          2
# pedagogy                                                          0
# ucla                                                              0
# university of pittsburgh                                          0
# university of virginia                                            0
#
#                                           university of virginia
#  blogging                                                      1
#  data visualization                                            1
#  databases                                                     1
#  machine learning/ai/buzzword tech stuff                       0
#  mapping                                                       1
#  pedagogy                                                      1
#  text mining                                                   1
#  website creation                                              0
# Golnar                                                         0
# Jack                                                           0
# Keanu                                                          0
# Lily                                                           0
# Paul                                                           0
# Richard                                                        0
# Sandra Kruse                                                   0
# Taylor                                                         0
# Zoe                                                            0
# cmu                                                            0
# data visualization                                             0
# duquesne university                                            0
# networks                                                       1
# pedagogy                                                       0
# ucla                                                           0
# university of pittsburgh                                       0
# university of virginia                                         0
#
# [25 rows x 25 columns]
# EdgeDataView([(' blogging', 'Golnar', {'weight': 1}), (' blogging', 'Jack', {'weight': 1}), (' blogging', 'Paul', {'weight': 1}), (' blogging', 'Richard', {'weight': 1}), (' blogging', 'Sandra Kruse', {'weight': 1}), (' blogging', 'Taylor ', {'weight': 1}), (' blogging', 'Zoe', {'weight': 1}), (' blogging', 'cmu', {'weight': 3}), (' blogging', 'duquesne university ', {'weight': 2}), (' blogging', 'university of pittsburgh ', {'weight': 1}), (' blogging', 'university of virginia', {'weight': 1}), (' data visualization', 'Golnar', {'weight': 1}), (' data visualization', 'Jack', {'weight': 1}), (' data visualization', 'Paul', {'weight': 1}), (' data visualization', 'Richard', {'weight': 2}), (' data visualization', 'Zoe', {'weight': 1}), (' data visualization', 'cmu', {'weight': 3}), (' data visualization', 'duquesne university ', {'weight': 1}), (' data visualization', 'university of pittsburgh ', {'weight': 1}), (' data visualization', 'university of virginia', {'weight': 1}), (' databases', 'Golnar', {'weight': 1}), (' databases', 'Paul', {'weight': 1}), (' databases', 'Richard', {'weight': 1}), (' databases', 'Sandra Kruse', {'weight': 1}), (' databases', 'Taylor ', {'weight': 1}), (' databases', 'Zoe', {'weight': 1}), (' databases', 'cmu', {'weight': 3}), (' databases', 'duquesne university ', {'weight': 1}), (' databases', 'university of pittsburgh ', {'weight': 1}), (' databases', 'university of virginia', {'weight': 1}), (' machine learning/ai/buzzword tech stuff', 'Keanu', {'weight': 1}), (' machine learning/ai/buzzword tech stuff', 'Paul', {'weight': 1}), (' machine learning/ai/buzzword tech stuff', 'Richard', {'weight': 2}), (' machine learning/ai/buzzword tech stuff', 'cmu', {'weight': 2}), (' machine learning/ai/buzzword tech stuff', 'duquesne university ', {'weight': 1}), (' machine learning/ai/buzzword tech stuff', 'ucla', {'weight': 1}), (' mapping', 'Golnar', {'weight': 1}), (' mapping', 'Lily ', {'weight': 1}), (' mapping', 'Paul', {'weight': 1}), (' mapping', 'Richard', {'weight': 1}), (' mapping', 'Zoe', {'weight': 1}), (' mapping', 'cmu', {'weight': 2}), (' mapping', 'university of pittsburgh ', {'weight': 2}), (' mapping', 'university of virginia', {'weight': 1}), (' pedagogy', 'Golnar', {'weight': 1}), (' pedagogy', 'Paul', {'weight': 1}), (' pedagogy', 'Richard', {'weight': 2}), (' pedagogy', 'Sandra Kruse', {'weight': 1}), (' pedagogy', 'Taylor ', {'weight': 1}), (' pedagogy', 'Zoe', {'weight': 1}), (' pedagogy', 'cmu', {'weight': 3}), (' pedagogy', 'duquesne university ', {'weight': 2}), (' pedagogy', 'university of pittsburgh ', {'weight': 1}), (' pedagogy', 'university of virginia', {'weight': 1}), (' text mining', 'Jack', {'weight': 1}), (' text mining', 'Paul', {'weight': 1}), (' text mining', 'Richard', {'weight': 2}), (' text mining', 'Zoe', {'weight': 1}), (' text mining', 'cmu', {'weight': 3}), (' text mining', 'duquesne university ', {'weight': 1}), (' text mining', 'university of virginia', {'weight': 1}), (' website creation', 'Golnar', {'weight': 1}), (' website creation', 'Jack', {'weight': 1}), (' website creation', 'Lily ', {'weight': 1}), (' website creation', 'Paul', {'weight': 1}), (' website creation', 'Richard', {'weight': 2}), (' website creation', 'Taylor ', {'weight': 1}), (' website creation', 'cmu', {'weight': 3}), (' website creation', 'duquesne university ', {'weight': 2}), (' website creation', 'university of pittsburgh ', {'weight': 2}), ('Golnar', 'networks', {'weight': 1}), ('Jack', 'networks', {'weight': 1}), ('Keanu', 'pedagogy', {'weight': 1}), ('Lily ', 'networks', {'weight': 1}), ('Paul', 'networks', {'weight': 1}), ('Richard', 'networks', {'weight': 2}), ('Sandra Kruse', 'data visualization', {'weight': 1}), ('Taylor ', 'data visualization', {'weight': 1}), ('Zoe', 'networks', {'weight': 1}), ('cmu', 'data visualization', {'weight': 1}), ('cmu', 'networks', {'weight': 3}), ('data visualization', 'duquesne university ', {'weight': 1}), ('duquesne university ', 'network ...
